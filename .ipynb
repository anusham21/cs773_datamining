# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
cd /Users/ajaygupta/Desktop/AM/CS773 Datamining/AM DATAMINING/final project/OULAD (1)/
# Out:
# /Users/ajaygupta/Desktop/AM/CS773 Datamining/AM DATAMINING/final project/OULAD (1)

# %%
df = pd.read_csv('studentInfo.csv')

# %%
df.head(10)
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
# 5         AAA             2013J       38053      M                 Wales
# 6         AAA             2013J       45462      M              Scotland
# 7         AAA             2013J       45642      F  North Western Region
# 8         AAA             2013J       52130      F   East Anglian Region
# 9         AAA             2013J       53025      M          North Region
#
#              highest_education imd_band age_band  num_of_prev_attempts  \
# 0             HE Qualification  90-100%     55<=                     0
# ...

# %%
df['gender'].value_counts()
# Out:
# M    17875
# F    14718
# Name: gender, dtype: int64

# %%
df1 = df.groupby(['code_module','code_presentation','gender']).size().reset_index(name = 'id_student')
df1
# Out:
#    code_module code_presentation gender  id_student
# 0          AAA             2013J      F         149
# 1          AAA             2013J      M         234
# 2          AAA             2014J      F         165
# 3          AAA             2014J      M         200
# 4          BBB             2013B      F        1559
# 5          BBB             2013B      M         208
# 6          BBB             2013J      F        1980
# 7          BBB             2013J      M         257
# 8          BBB             2014B      F        1434
# 9          BBB             2014B      M         179
# 10         BBB             2014J      F        2018
# 11         BBB             2014J      M         274
# 12         CCC             2014B      F         456
# 13         CCC             2014B      M        1480
# 14         CCC             2014J      F         645
# 15         CCC             2014J      M        1853
# 16         DDD             2013B      F         518
# ...

# %%
df1['id_student'].max()
# Out:
# 2018
